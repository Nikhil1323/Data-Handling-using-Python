# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#to drop a particular column
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis=1) 
#here the drop function is used to temporarily delete the row or column
#the parameter of drop i.e axis is bydefault set to 0 which means it will search for the rows whose name 
#we have passed to drop.
# to make python scan the table column wise we need to make the axis as 1.
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df # here the original data frame remains the same.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#when we make the inplace parameter true the drop is permanent and not only in the run time.
#bydefault the inplace is False.

# %%
#to make any particular column as the index we CAN DO The following.
df.set_index("Name") # it effects only in the ruun time and is not permanent.
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.set_index("Name", inplace=True)

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.reset_index() # it brings back the dafault index back
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
d = {"key1": [3,4,5,6,7],
     "key2" :[5,6,7,8,6],
     "key3" :[4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
df1 = pd.read_csv('services.csv')

# %%
#to drop NaN
df1
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df1.dropna()
# Out:
# Empty DataFrame
# Columns: [id, location_id, program_id, accepted_payments, alternate_name, application_process, audience, description, eligibility, email, fees, funding_sources, interpretation_services, keywords, languages, name, required_documents, service_areas, status, wait_time, website, taxonomy_ids]
# Index: []
#
# [0 rows x 22 columns]

# %%
df2 = pd.read_excel("sampledataworkorders.xlsx",sheet_name='WOs')

# %%
df2
# Out:
#          WO   District LeadTech  Service Rush    ReqDate   WorkDate  Techs  \
# 0    A00100      North     Khan   Assess  NaN 2020-09-01 2020-09-15      2
# 1    A00101      South    Lopez  Replace  NaN 2020-09-01 2020-09-04      1
# 2    A00102    Central  Cartier  Deliver  NaN 2020-09-01 2020-09-17      1
# 3    A00103      South    Lopez  Deliver  NaN 2020-09-01 2020-09-17      1
# 4    A00104  Northwest  Cartier  Deliver  Yes 2020-09-01 2020-09-17      1
# ..      ...        ...      ...      ...  ...        ...        ...    ...
# 995  A01095  Southeast   Burton   Assess  NaN 2021-07-22        NaT      2
# 996  A01096  Northwest  Cartier   Repair  NaN 2021-07-22        NaT      1
# 997  A01097    Central  Cartier   Assess  NaN 2021-07-23        NaT      1
# 998  A01098       East     Ling  Deliver  NaN 2021-07-24        NaT      1
# 999  A01100       East     Ling   Assess  NaN 2021-07-29        NaT      2
#
# ...

# %%
df2.dropna(axis = 1,inplace=True)

# %%
df2.dropna()
# Out:
#          WO   District LeadTech  Service    ReqDate  Techs  PartsCost  \
# 0    A00100      North     Khan   Assess 2020-09-01      2   360.0000
# 1    A00101      South    Lopez  Replace 2020-09-01      1    90.0416
# 2    A00102    Central  Cartier  Deliver 2020-09-01      1   120.0000
# 3    A00103      South    Lopez  Deliver 2020-09-01      1    16.2500
# 4    A00104  Northwest  Cartier  Deliver 2020-09-01      1    45.2374
# ..      ...        ...      ...      ...        ...    ...        ...
# 995  A01095  Southeast   Burton   Assess 2021-07-22      2   237.2100
# 996  A01096  Northwest  Cartier   Repair 2021-07-22      1   128.8115
# 997  A01097    Central  Cartier   Assess 2021-07-23      1    84.8862
# 998  A01098       East     Ling  Deliver 2021-07-24      1   122.3195
# 999  A01100       East     Ling   Assess 2021-07-29      2   210.4494
#
#      Payment  LbrRate  LbrCost  LbrFee  PartsFee  TotalCost  TotalFee ReqDay  \
# ...

# %%
df3 = pd.read_csv('services.csv')

# %%
df3
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.dropna()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# McCarthy, Mr. Timothy J                                       7         0
# Sandstrom, Miss. Marguerite Rut                              11         1
# Bonnell, Miss. Elizabeth                                     12         1
# Beesley, Mr. Lawrence                                        22         1
# ...                                                         ...       ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            872         1
# Carlsson, Mr. Frans Olof                                    873         0
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880         1
# Graham, Miss. Margaret Edith                                888         1
# Behr, Mr. Karl Howell                                       890         1
#
# ...

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.fillna("Nikhil")
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
#to perform group by operation

# %%
g = df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_820/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199
# 1              151970     666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_820/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          445.659824  1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1 = df.groupby("Pclass")

# %%
g1

# %%
g1.sum()
# Out:
# /tmp/ipykernel_820/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99701       135  7076.42     89     77  18124.3125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_820/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        463.725581  0.627907  38.250919  0.413953  0.358140  84.299128
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.min()
# Out:
# /tmp/ipykernel_820/1946832900.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   g1.min()
#                                  Name  PassengerId  Survived     Sex   Age  \
# Pclass
# 1       Allen, Miss. Elisabeth Walton            2         0  female  0.92
# 2                 Abelson, Mr. Samuel           10         0  female  0.67
# 3                 Abbing, Mr. Anthony            1         0  female  0.42
#
#         SibSp  Parch  Ticket  Fare
# Pclass
# 1           0      0  110152   0.0
# 2           0      0   11668   0.0
# 3           0      0   12460   0.0

# %%
g1.max()
# Out:
# /tmp/ipykernel_820/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  PassengerId  Survived   Sex   Age  SibSp  \
# Pclass
# 1          Young, Miss. Marie Grice          890         1  male  80.0      3
# 2         del Carlo, Mr. Sebastiano          887         1  male  70.0      3
# 3       van Melkebeke, Mr. Philemon          891         1  male  74.0      8
#
#         Parch      Ticket      Fare
# Pclass
# 1           4   WE/P 5735  512.3292
# 2           3   W/C 14208   73.5000
# 3           6  W./C. 6609   69.5500

# %%
g1.max().T #To transpose the data. that is interchanging rows and columns
# Out:
# /tmp/ipykernel_820/4292632772.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T #To transpose the data. that is interchanging rows and columns
# Pclass                              1                          2  \
# Name         Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# PassengerId                       890                        887
# Survived                            1                          1
# Sex                              male                       male
# Age                              80.0                       70.0
# SibSp                               3                          3
# Parch                               4                          3
# Ticket                      WE/P 5735                  W/C 14208
# Fare                         512.3292                       73.5
#
# ...

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
#to make subset of the data
df5 = df[['Name','Survived','Pclass']][0:5]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
#to merge two data frames
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df7 = pd.concat([df5,df6],axis = 1)

# %%
df7.fillna('Nikhil')
# Out:
#                                                 Name Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0     1.0
# 2                             Heikkinen, Miss. Laina      1.0     3.0
# 3                           Allen, Mr. William Henry      0.0     3.0
# 4                                   Moran, Mr. James      0.0     3.0
# 5                                             Nikhil   Nikhil  Nikhil
# 6                                             Nikhil   Nikhil  Nikhil
# 7                                             Nikhil   Nikhil  Nikhil
# 8                                             Nikhil   Nikhil  Nikhil
# 9                                             Nikhil   Nikhil  Nikhil
#
#                                                 Name Survived  Pclass
# 0                                             Nikhil   Nikhil  Nikhil
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,3,4,5,6],'key2':[4,5,6,7,8,9],
                     'key3' :[1,5,9,7,5,3]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     1
# 1     2     5     5
# 2     3     6     9
# 3     4     7     7
# 4     5     8     5
# 5     6     9     3

# %%
data2 = pd.DataFrame({'key1':[1,2,45,8,5,6],'key4':[4,5,6,77,8,9],
                     'key5' :[1,5,9,478,5,3]})

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     4     1
# 1     2     5     5
# 2    45     6     9
# 3     8    77   478
# 4     5     8     5
# 5     6     9     3

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     1     4     1
# 1     2     5     5     5     5
# 2     5     8     5     8     5
# 3     6     9     3     9     3

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     1   4.0   1.0
# 1     2     5     5   5.0   5.0
# 2     3     6     9   NaN   NaN
# 3     4     7     7   NaN   NaN
# 4     5     8     5   8.0   5.0
# 5     6     9     3   9.0   3.0

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     1
# 1     2     5     5
# 2     3     6     9
# 3     4     7     7
# 4     5     8     5
# 5     6     9     3

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     4     1
# 1     2     5     5
# 2    45     6     9
# 3     8    77   478
# 4     5     8     5
# 5     6     9     3

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   1.0     4     1
# 1     2   5.0   5.0     5     5
# 2    45   NaN   NaN     6     9
# 3     8   NaN   NaN    77   478
# 4     5   8.0   5.0     8     5
# 5     6   9.0   3.0     9     3

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key4   key5
# 0     1   4.0   1.0   4.0    1.0
# 1     2   5.0   5.0   5.0    5.0
# 2     3   6.0   9.0   NaN    NaN
# 3     4   7.0   7.0   NaN    NaN
# 4     5   8.0   5.0   8.0    5.0
# 5     6   9.0   3.0   9.0    3.0
# 6    45   NaN   NaN   6.0    9.0
# 7     8   NaN   NaN  77.0  478.0

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     1       1     4     1
# 1        1     4     1       2     5     5
# 2        1     4     1      45     6     9
# 3        1     4     1       8    77   478
# 4        1     4     1       5     8     5
# 5        1     4     1       6     9     3
# 6        2     5     5       1     4     1
# 7        2     5     5       2     5     5
# 8        2     5     5      45     6     9
# 9        2     5     5       8    77   478
# 10       2     5     5       5     8     5
# 11       2     5     5       6     9     3
# 12       3     6     9       1     4     1
# 13       3     6     9       2     5     5
# 14       3     6     9      45     6     9
# 15       3     6     9       8    77   478
# 16       3     6     9       5     8     5
# 17       3     6     9       6     9     3
# 18       4     7     7       1     4     1
# 19       4     7     7       2     5     5
# 20       4     7     7      45     6     9
# ...

# %%
pd.merge(data1,data2,how='outer', on = 'key1')
# Out:
#    key1  key2  key3  key4   key5
# 0     1   4.0   1.0   4.0    1.0
# 1     2   5.0   5.0   5.0    5.0
# 2     3   6.0   9.0   NaN    NaN
# 3     4   7.0   7.0   NaN    NaN
# 4     5   8.0   5.0   8.0    5.0
# 5     6   9.0   3.0   9.0    3.0
# 6    45   NaN   NaN   6.0    9.0
# 7     8   NaN   NaN  77.0  478.0

# %%
import pandas as pd
data1 = pd.DataFrame({'key1':[1,2,3,4,5,6],'key2':[4,5,6,7,8,9],
                     'key3' :[1,5,9,7,5,3]},
                    index = ['a','b','c','d','e','f']
                    )

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     1
# b     2     5     5
# c     3     6     9
# d     4     7     7
# e     5     8     5
# f     6     9     3

# %%
data2 = pd.DataFrame({'key11':[1,2,3,4,5,6],'key22':[4,5,6,7,8,9],
                     'key33' :[1,5,9,7,5,3]},
                    index = ['e','f','g','h','i','j']
                    )

# %%
data2
# Out:
#    key11  key22  key33
# e      1      4      1
# f      2      5      5
# g      3      6      9
# h      4      7      7
# i      5      8      5
# j      6      9      3

# %%
data1.join(data2,how ='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# e   5.0   8.0   5.0      1      4      1
# f   6.0   9.0   3.0      2      5      5
# g   NaN   NaN   NaN      3      6      9
# h   NaN   NaN   NaN      4      7      7
# i   NaN   NaN   NaN      5      8      5
# j   NaN   NaN   NaN      6      9      3

# %%
data1.join(data2,how = 'cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     1      1      4      1
# 1      1     4     1      2      5      5
# 2      1     4     1      3      6      9
# 3      1     4     1      4      7      7
# 4      1     4     1      5      8      5
# 5      1     4     1      6      9      3
# 6      2     5     5      1      4      1
# 7      2     5     5      2      5      5
# 8      2     5     5      3      6      9
# 9      2     5     5      4      7      7
# 10     2     5     5      5      8      5
# 11     2     5     5      6      9      3
# 12     3     6     9      1      4      1
# 13     3     6     9      2      5      5
# 14     3     6     9      3      6      9
# 15     3     6     9      4      7      7
# 16     3     6     9      5      8      5
# 17     3     6     9      6      9      3
# 18     4     7     7      1      4      1
# 19     4     7     7      2      5      5
# 20     4     7     7      3      6      9
# ...

# %%
#Join works on index value and merge works on column values

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
#to convert fare in rupees from euros

df['Fare_inr'] = df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr
# 0        S   580.000
# 1        C  5702.664
# ...

# %%
def euro_inr(x):
    return x*80
df['Fare_inr'] = df['Fare'].apply(euro_inr)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr
# 0        S   580.000
# 1        C  5702.664
# ...

# %%
df['Name_len'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr  Name_len
# 0        S   580.000        23
# ...

# %%
def category_fare(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "Mid"
    else:
        return "High"

# %%
df['cat_fare'] = df['Fare'].apply(category_fare)

# %%
df.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked  Fare_inr  Name_len cat_fare
# 0        S   580.000        23    cheap
# ...
